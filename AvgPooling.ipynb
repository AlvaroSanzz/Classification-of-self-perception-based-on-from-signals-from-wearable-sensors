# %% [markdown]
# <a href="https://colab.research.google.com/github/AlvaroSanzz/Classification-of-self-perception-based-on-from-signals-from-wearable-sensors/blob/main/AvgPooling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import numpy as np
import xlrd
from torch.utils.data import Dataset
import pandas as pd
from sklearn.preprocessing import StandardScaler
from torch.utils.data import random_split, DataLoader
from sklearn.model_selection import train_test_split
import torch.nn as nn
import torch.nn.functional as F

# %%
#Antes de nada, si tenemos GPU la utilizamos
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

print(device)
# Out:
# cuda:0

# %%
from shutil import copyfile
from google.colab import drive
import os, sys
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# # Superprocesado

# %%
import pandas as pd
import numpy as np
import torch
from torch.utils.data import DataLoader, random_split
from sklearn.preprocessing import StandardScaler
import os
import glob

def process_excel(df):

    # Crear una lista de palabras clave a buscar en los nombres de las columnas
    palabras_clave = ["position", "acceleration", "velocity", "time"]

    # Encontrar las columnas que contienen alguna de las palabras clave en su nombre
    columnas_a_eliminar = []
    contador = 0
    for columna in df.columns:
        if any(palabra in columna.lower() for palabra in palabras_clave):
            columnas_a_eliminar.append(columna)

    # Eliminar las columnas encontradas
    df = df.drop(columns=columnas_a_eliminar)

    # Iterar sobre las filas del DataFrame en orden inverso para ajustar etiquetas
    ultimo_valor_no_cero = 0
    for indice, fila in df[::-1].iterrows():
        if fila['Label'] != 0:
            ultimo_valor_no_cero = fila['Label']
        else:
            df.at[indice, 'Label'] = ultimo_valor_no_cero

    # Eliminar filas después del último valor no cero en 'Label'
    ultimo_valor_no_cero = df.loc[df['Label'] != 0, 'Label'].iloc[-1]
    indice_ultimo_no_cero = df.loc[df['Label'] == ultimo_valor_no_cero].index[-1]
    df = df.iloc[:indice_ultimo_no_cero + 1]

    # Estandarizar columnas
    df = estandarizar_columnas(df)

    # Crear ventanas
    win_size = 300
    stp = 150
    ventanas = sliding_window_np(df, win_size, stp)

    return ventanas

def estandarizar_columnas(df):
    columnas_excluidas = ['Label']
    columnas_estandarizar = [col for col in df.columns if col not in columnas_excluidas]
    scaler = StandardScaler()
    df[columnas_estandarizar] = scaler.fit_transform(df[columnas_estandarizar])
    return df

def sliding_window_np(df, window_size, step):
    num_windows = (df.shape[0] - window_size) // step + 1
    windows = []
    for i in range(num_windows):
        start = i * step
        end = start + window_size
        window = df.iloc[start:end, :]  # Asegurarse de que la ventana tenga exactamente 'window_size' filas
        if window['Label'].nunique() == 1:
            windows.append(window)
    return windows

def one_hot_encode(labels, num_classes):
    one_hot_labels = np.zeros((len(labels), num_classes))
    for i, label in enumerate(labels):
        one_hot_labels[i, label - 1] = 1
    return one_hot_labels

def windows_to_tensors(windows, num_classes):
    tensors = []
    for window in windows:
        features = window.iloc[:, :-1].values
        labels = window.iloc[0, -1]
        labels_one_hot = one_hot_encode([labels], num_classes)[0]
        features_tensor = torch.tensor(features, dtype=torch.float32)
        labels_tensor = torch.tensor(labels_one_hot, dtype=torch.float32)
        tensors.append((features_tensor, labels_tensor))
    return tensors


# Clase para añadir ruido gaussiano
class GaussianNoiseTransform:
    def __init__(self, mean=0.0, std=1.0):
        self.mean = mean
        self.std = std

    def __call__(self, tensor):
        noise = torch.randn(tensor.size()) * self.std + self.mean
        return tensor + noise

# Clase de dataset personalizada
class CustomDataset(Dataset):
    def __init__(self, data, transform=None):
        self.data = data
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        x, y = self.data[idx]
        if self.transform:
            x = self.transform(x)
        return x, y

# %%
all_windows = []
num_classes = 7

path = '/content/drive/My Drive/TFG/RokokoFiles/'

# Buscar todos los archivos CSV en el directorio actual
csv_files = glob.glob(path + '*.csv')

print(csv_files)

# Leer cada archivo CSV y almacenarlos en DataFrames separados

for file in csv_files:
  df = pd.read_csv(file)

  # for file_path in file_paths:
  ventanas = process_excel(df)
  tensor_data = windows_to_tensors(ventanas, num_classes)
  all_windows.extend(tensor_data)

print("EL numero de ventanas es: ", len(all_windows))
print("EL numero de ventanas es: ", len(ventanas))
print("El numero de filas y columnas de cada ventana es: ",ventanas[0].shape)


# Dividir los datos combinados en conjuntos de entrenamiento y prueba
generator = torch.Generator().manual_seed(42)
train_val_size = int(0.8 * len(all_windows))  # Supongamos que queremos el 80% para entrenamiento y validación combinados
test_val_size = len(all_windows) - train_val_size

trainset, testset = random_split(all_windows, [train_val_size, test_val_size], generator=generator)


# Añadir ruido gaussiano solo al conjunto de entrenamiento
gaussian_transform = GaussianNoiseTransform(mean=0.0, std=0.1)
trainset = CustomDataset(trainset, transform=gaussian_transform)
# Out:
# ['/content/drive/My Drive/TFG/RokokoFiles/[p185] control-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p185] high-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p185] high-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p185] low-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p186] control-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p186] control-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p186] high-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p186] high-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p186] low-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p188] control-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p188] control-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p188] high-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p188] high-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p188] low-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p188] low-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p189] control-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p189] control-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p189] high-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p189] low-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p192] control-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p192] control-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p192] high-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p192] low-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p192] low-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p193] control-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p193] high-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p193] control-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p193] low-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p193] high-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p193] low-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p195] control-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p195] control-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p195] high-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p195] high-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p195] low-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p195] low-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p197] control-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p197] control-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p197] high-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p197] high-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p197] low-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p197] low-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p201] control-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p201] control-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p201] high-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p201] low-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p202] control-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p202] control-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p202] high-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p202] low-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p205] control-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p205] low-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p205] high-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p205] low-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p206] control-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p206] high-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p206] high-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p206] low-1 Rokoko.csv', '/content/ ...
# EL numero de ventanas es:  11563
# EL numero de ventanas es:  45
# El numero de filas y columnas de cada ventana es:  (300, 52)

# %%
class CustomDataLoader_4D(DataLoader):
    def __init__(self, dataset, batch_size, shuffle, add_channel_dim=True):
        super().__init__(dataset, batch_size, shuffle)
        self.add_channel_dim = add_channel_dim

    def __iter__(self):
        for batch in super().__iter__():
            if self.add_channel_dim:
                batch = self.add_channel_dimension(batch)
            yield batch

    def add_channel_dimension(self, batch):
        data, labels = batch
        data = data.unsqueeze(1)  # Agregar una dimensión de canal
        return data, labels

batch_size = 16
trainloader = CustomDataLoader_4D(trainset, batch_size, shuffle=True)
testloader = CustomDataLoader_4D(testset, batch_size, shuffle=False)

# Verificar la forma del primer lote de datos
for batch_data, batch_labels in trainloader:
    print("Dimensiones del lote de datos:", batch_data.shape)
    print("Dimensiones del lote de etiquetas:", batch_labels.shape)
    break  # Detener después de imprimir el primer lote
# Out:
# Dimensiones del lote de datos: torch.Size([16, 1, 300, 51])
# Dimensiones del lote de etiquetas: torch.Size([16, 7])

# %%
print("Tamaño del conjunto de entrenamiento:", len(trainset))
print("Tamaño del conjunto de test:", len(testset))
# Out:
# Tamaño del conjunto de entrenamiento: 9250
# Tamaño del conjunto de test: 2313

# %% [markdown]
# # Constucción de la red

# %% [markdown]
# Primero definiremos las capas

# %%
class Net(nn.Module):
  def __init__(self):
      super(Net, self).__init__()

      # Bloque #1
      self.conv1 = nn.Conv2d(1, 4, 3, padding=1) #poner padding 1
      self.bn1 = nn.BatchNorm2d(4)
      self.conv2 = nn.Conv2d(4, 8, 3, padding=1)
      self.bn2 = nn.BatchNorm2d(8)

      # Bloque #2
      self.conv3 = nn.Conv2d(8, 16, 3, padding=1)
      self.bn3 = nn.BatchNorm2d(16)
      self.conv4 = nn.Conv2d(16, 32, 3, padding=1)
      self.bn4 = nn.BatchNorm2d(32)

      # Bloque #3
      self.conv5 = nn.Conv2d(32, 64, 3, padding=1)
      self.bn5 = nn.BatchNorm2d(64)
      self.conv6 = nn.Conv2d(64, 128, 3, padding=1)
      self.bn6 = nn.BatchNorm2d(128)

      # Bloque #4
      self.conv7 = nn.Conv2d(128, 256, 3, padding=1)
      self.bn7 = nn.BatchNorm2d(256)
      self.conv8 = nn.Conv2d(256, 512, 3, padding=1)
      self.bn8 = nn.BatchNorm2d(512)

      self.pool = nn.MaxPool2d(3, stride=(2, 1), padding=1)

      self.avgpool = nn.AdaptiveAvgPool2d((1, 1))

      self.fc1 = nn.Linear(512, 128)
      self.fc2 = nn.Linear(128, 256)
      self.fc3 = nn.Linear(256, 7)

      self.bn1d1 = nn.BatchNorm1d(128)
      self.bn1d2 = nn.BatchNorm1d(256)

      self.dropout1 = nn.Dropout(p=0.5)
      self.dropout2 = nn.Dropout(p=0.5)

  def forward(self, x):


    x = F.relu(self.bn1(self.conv1(x)))
    x = self.pool(F.relu(self.bn2(self.conv2(x))))

    x = F.relu(self.bn3(self.conv3(x)))
    x = self.pool(F.relu(self.bn4(self.conv4(x))))

    x = F.relu(self.bn5(self.conv5(x)))
    x = self.pool(F.relu(self.bn6(self.conv6(x))))

    x = F.relu(self.bn7(self.conv7(x)))
    x = self.pool(F.relu(self.bn8(self.conv8(x))))

    # x = x.flatten(start_dim=1)

    x = self.avgpool(x)
    x = x.flatten(start_dim=1)

    x = F.relu(self.bn1d1(self.fc1(x)))
    # x = self.dropout1(x)
    x = F.relu(self.bn1d2(self.fc2(x)))
    # x = self.dropout2(x)
    x = self.fc3(x)

    return x

# %%
import random
import numpy.random as npr

#We fix seeds for reproducibility
random.seed(42)
npr.seed(42)
torch.manual_seed(42)
torch.backends.cudnn.benchmark = True

net = Net() #Invocamos el constructor de la red (método init())
net.to(device) #Pasamos la red al device que estemos usando (gpu)
# Out:
# Net(
#   (conv1): Conv2d(1, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(4, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn2): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn3): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv5): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv6): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn6): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv7): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn7): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv8): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn8): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool): MaxPool2d(kernel_size=3, stride=(2, 1), padding=1, dilation=1, ceil_mode=False)
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc1): Linear(in_features=512, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=7, bias=True)
#   (bn1d1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn1d2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout1): Dropout(p=0.5, inplace=False)
#   (dropout2): Dropout(p=0.5, inplace=False)
# )

# %% [markdown]
# Testeo para comprobar la dimension de nuestros datos al entrar al salir de la red

# %% [markdown]
# # Entrenamiento

# %%
data=next(iter(trainloader))
inputs = data[0].to(device).float()  # Tomamos la primera imagen y le agregamos una dimensión de lote
labels = data[1].to(device)  # Tomamos la primera etiqueta y le agregamos una dimensión de lote

x = inputs.to(device)
print(x.shape)

print("Forma de la imagen:", inputs.shape)
print("Forma de la etiqueta:", labels.shape)
with torch.set_grad_enabled(False):
    outputs = net(inputs)

    print('El tamaño del tensor de salida es {}'.format(outputs.shape))
# Out:
# torch.Size([16, 1, 300, 51])
# Forma de la imagen: torch.Size([16, 1, 300, 51])
# Forma de la etiqueta: torch.Size([16, 7])
# El tamaño del tensor de salida es torch.Size([16, 7])

# %%
def train_loop(trainDataloader, model, criterion, optimizer):
    size = len(trainDataloader.dataset)
    epoch_loss = 0.0  # Inicializar la pérdida de la época
    epoch_correct = 0.0

    for inputs, labels in trainDataloader:  # Iterar sobre el dataloader
      inputs = inputs.to(device).float()  # Mover las imágenes al dispositivo y convertirlas a flotantes
      labels = labels.to(device)  # Mover las etiquetas al dispositivo

      y_pred = model(inputs)  # Realizar predicciones
      loss = criterion(y_pred, labels)  # Calcular la pérdida

      optimizer.zero_grad()  # Reiniciar los gradientes
      loss.backward()  # Realizar la retropropagación
      optimizer.step()  # Actualizar los parámetros

      epoch_loss += loss.item()  # Acumular la pérdida de la muestra actual en la pérdida de la época
      epoch_correct += torch.sum( torch.argmax(y_pred, axis=1) == torch.argmax(labels, axis=1)).item()

    epoch_loss /= len(trainloader)  # Calcular el promedio de la pérdida de la época
    epoch_correct /= size
    print(f"Train Error:\n Accuracy: {(100 * epoch_correct):>0.1f}%, Perdida train: {epoch_loss:>5f}\n")
    return epoch_loss, epoch_correct

def validation_loop(dataloader, model, criterion):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    total_correct = 0
    total_loss = 0
    all_preds = []
    all_labels = []
    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs = inputs.to(device).float()
            labels = labels.to(device)
            y_pred = model(inputs)
            loss = criterion(y_pred, labels)
            indicemax = torch.argmax(y_pred, axis=1)
            predicted_onehot = torch.zeros_like(y_pred)
            # predicted_onehot[indicemax] = 1
            predicted_labels = torch.argmax(y_pred, axis=1)  # Obtener la etiqueta predicha unidimensional
            true_labels = torch.argmax(labels, axis=1) #etiqueta verdadera unidimensional
            total_loss += loss.item()
            all_preds.extend(torch.argmax(y_pred, axis=1).cpu().numpy())
            all_labels.extend(torch.argmax(labels, axis=1).cpu().numpy())

            # print("y_pred: ", y_pred)
            # print("labels: ", labels)

            # Calcular el número total de predicciones correctas
            total_correct += torch.sum( torch.argmax(y_pred, axis=1) == torch.argmax(labels, axis=1)).item()
    # Calcular la precisión y la pérdida promedio
    total_correct /= size
    total_loss /= num_batches
    print(f"Validation Error:\n Accuracy: {(100 * total_correct):>0.1f}%, Perdida test: {total_loss:>5f}\n")
    return total_loss, total_correct, all_labels, all_preds

# %%
num_epochs = 150
criterion = torch.nn.CrossEntropyLoss()
model = Net().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, weight_decay=0.005)

# Añadir un StepLR scheduler
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=30, gamma=0.1)

loss_train, accu_train = np.zeros(num_epochs), np.zeros(num_epochs)
loss_validation, accu_validation = np.zeros(num_epochs), np.zeros(num_epochs)

for epoch in range(num_epochs):
    print(f"Epoca {epoch + 1}/{num_epochs}")
    loss_train[epoch], accu_train[epoch] = train_loop(trainloader, model, criterion, optimizer)
    loss_validation[epoch], accu_validation[epoch], all_labels, all_preds = validation_loop(testloader, model, criterion)

    # Actualizar el learning rate según el scheduler
    scheduler.step()

    print("----------------------------------")
# Out:
# Epoca 1/150
# Train Error:
#  Accuracy: 24.5%, Perdida train: 1.803269
#
# Validation Error:
#  Accuracy: 27.4%, Perdida test: 1.732281
#
# ----------------------------------
# Epoca 2/150
# Train Error:
#  Accuracy: 29.2%, Perdida train: 1.712196
#
# Validation Error:
#  Accuracy: 31.0%, Perdida test: 1.652787
#
# ----------------------------------
# Epoca 3/150
# Train Error:
#  Accuracy: 32.7%, Perdida train: 1.630566
#
# Validation Error:
#  Accuracy: 32.0%, Perdida test: 1.623907
#
# ----------------------------------
# Epoca 4/150
# Train Error:
#  Accuracy: 38.2%, Perdida train: 1.542963
#
# Validation Error:
#  Accuracy: 35.1%, Perdida test: 1.572447
#
# ----------------------------------
# Epoca 5/150
# Train Error:
#  Accuracy: 39.8%, Perdida train: 1.487163
#
# Validation Error:
#  Accuracy: 40.4%, Perdida test: 1.476688
#
# ----------------------------------
# Epoca 6/150
# Train Error:
#  Accuracy: 46.4%, Perdida train: 1.358178
#
# Validation Error:
#  Accuracy: 44.0%, Perdida test: 1.431530
#
# ----------------------------------
# Epoca 7/150
# Train Error:
#  Accuracy: 52.4%, Perdida train: 1.252333
#
# Validation Error:
#  Accuracy: 44.0%, Perdida test: 1.373807
#
# ----------------------------------
# Epoca 8/150
# Train Error:
#  Accuracy: 55.3%, Perdida train: 1.170933
#
# Validation Error:
#  Accuracy: 47.5%, Perdida test: 1.326548
#
# ----------------------------------
# Epoca 9/150
# Train Error:
#  Accuracy: 57.2%, Perdida train: 1.128265
#
# Validation Error:
#  Accuracy: 48.1%, Perdida test: 1.286019
#
# ----------------------------------
# Epoca 10/150
# Train Error:
#  Accuracy: 63.0%, Perdida train: 0.994147
#
# Validation Error:
#  Accuracy: 52.7%, Perdida test: 1.235499
#
# ----------------------------------
# Epoca 11/150
# Train Error:
#  Accuracy: 68.7%, Perdida train: 0.869001
#
# Validation Error:
#  Accuracy: 55.2%, Perdida test: 1.185668
#
# ----------------------------------
# Epoca 12/150
# Train Error:
#  Accuracy: 70.4%, Perdida train: 0.808253
#
# Validation Error:
#  Accuracy: 56.5%, Perdida test: 1.176756
#
# ----------------------------------
# Epoca 13/150
# Train Error:
#  Accuracy: 71.1%, Perdida train: 0.802572
#
# Validation Error:
#  Accuracy: 58.2%, Perdida test: 1.121299
#
# ----------------------------------
# Epoca 14/150
# Train Error:
#  Accuracy: 76.7%, Perdida train: 0.664173
#
# Validation Error:
#  Accuracy: 58.7%, Perdida test: 1.117082
#
# ----------------------------------
# Epoca 15/150
# Train Error:
#  Accuracy: 77.9%, Perdida train: 0.624049
#
# Validation Error:
#  Accuracy: 62.5%, Perdida test: 1.032343
#
# ----------------------------------
# Epoca 16/150
# Train Error:
#  Accuracy: 80.8%, Perdida train: 0.551997
#
# Validation Error:
#  Accuracy: 61.9%, Perdida test: 1.073643
#
# ----------------------------------
# Epoca 17/150
# Train Error:
#  Accuracy: 81.6%, Perdida train: 0.532240
#
# Validation Error:
#  Accuracy: 65.2%, Perdida test: 0.980652
#
# ----------------------------------
# Epoca 18/150
# Train Error:
#  Accuracy: 85.3%, Perdida train: 0.444193
#
# Validation Error:
#  Accuracy: 67.3%, Perdida test: 0.916072
#
# ----------------------------------
# Epoca 19/150
# Train Error:
#  Accuracy: 84.7%, Perdida train: 0.440127
#
# Validation Error:
#  Accuracy: 67.8%, Perdida test: 0.926533
#
# ----------------------------------
# Epoca 20/150
# Train Error:
#  Accuracy: 86.1%, Perdida train: 0.422368
#
# Validation Error:
#  Accuracy: 68.2%, Perdida test: 0.903757
#
# ----------------------------------
# Epoca 21/150
# Train Error:
#  Accuracy: 87.0%, Perdida train: 0.392182
#
# Validation Error:
#  Accuracy: 68.5%, Perdida test: 0.900987
#
# ----------------------------------
# Epoca 22/150
# Train Error:
#  Accuracy: 84.4%, Perdida train: 0.457498
#
# Validation Error:
#  Accuracy: 67.4%, Perdida test: 0.927933
#
# ----------------------------------
# Epoca 23/150
# Train Error:
#  Accuracy: 87.1%, Perdida train: 0.388986
#
# Validation Error:
#  Accuracy: 71.6%, Perdida test: 0.828277
#
# ----------------------------------
# Epoca 24/150
# Train Error:
#  Accuracy: 91.1%, Perdida train: 0.275231
#
# Validation Error:
#  Accuracy: 70.6%, Perdida test: 0.870152
#
# ----------------------------------
# Epoca 25/150
# Train Error:
#  Accuracy: 91.5%, Perdida train: 0.273252
#
# Validation Error:
#  Accuracy: 70.3%, Perdida test: 0.875783
#
# ----------------------------------
# Epoca 26/150
# Train Error:
#  Accuracy: 88.4%, Perdida train: 0.338768
#
# Validation Error:
#  Accuracy: 71.9%, Perdida test: 0.846976
#
# ----------------------------------
# Epoca 27/150
# Train Error:
#  Accuracy: 92.0%, Perdida train: 0.253302
#
# Validation Error:
#  Accuracy: 73.4%, Perdida test: 0.804431
#
# ----------------------------------
# Epoca 28/150
# Train Error:
#  Accuracy: 91.6%, Perdida train: 0.255458
#
# Validation Error:
#  Accuracy: 71.8%, Perdida test: 0.871995
#
# ----------------------------------
# Epoca 29/150
# Train Error:
#  Accuracy: 90.2%, Perdida train: 0.293157
#
# Validation Error:
#  Accuracy: 73.4%, Perdida test: 0.809026
#
# ----------------------------------
# Epoca 30/150
# Train Error:
#  Accuracy: 93.0%, Perdida train: 0.225769
#
# Validation Error:
#  Accuracy: 74.6%, Perdida test: 0.776696
#
# ----------------------------------
# Epoca 31/150
# Train Error:
#  Accuracy: 97.5%, Perdida train: 0.116202
#
# Validation Error:
#  Accuracy: 80.9%, Perdida test: 0.604231
#
# ----------------------------------
# Epoca 32/150
# Train Error:
#  Accuracy: 98.6%, Perdida train: 0.079982
#
# Validation Error:
#  Accuracy: 81.8%, Perdida test: 0.584566
#
# ----------------------------------
# Epoca 33/150
# Train Error:
#  Accuracy: 99.1%, Perdida train: 0.065493
#
# Validation Error:
#  Accuracy: 82.1%, Perdida test: 0.563114
#
# ----------------------------------
# Epoca 34/150
# Train Error:
#  Accuracy: 99.1%, Perdida train: 0.063984
#
# Validation Error:
#  Accuracy: 82.5%, Perdida test: 0.553671
#
# ----------------------------------
# Epoca 35/150
# Train Error:
#  Accuracy: 99.4%, Perdida train: 0.056019
#
# Validation Error:
#  Accuracy: 83.1%, Perdida test: 0.549149
#
# ----------------------------------
# Epoca 36/150
# Train Error:
#  Accuracy: 99.4%, Perdida train: 0.052920
#
# Validation Error:
#  Accuracy: 82.9%, Perdida test: 0.544425
#
# ----------------------------------
# Epoca 37/150
# Train Error:
#  Accuracy: 99.2%, Perdida train: 0.056228
#
# Validation Error:
#  Accuracy: 82.7%, Perdida test: 0.542530
#
# ----------------------------------
# Epoca 38/150
# Train Error:
#  Accuracy: 99.4%, Perdida train: 0.048565
#
# Validation Error:
#  Accuracy: 83.3%, Perdida test: 0.540085
#
# ----------------------------------
# Epoca 39/150
# Train Error:
#  Accuracy: 99.4%, Perdida train: 0.054872
#
# Validation Error:
#  Accuracy: 83.7%, Perdida test: 0.516715
#
# ----------------------------------
# Epoca 40/150
# Train Error:
#  Accuracy: 99.4%, Perdida train: 0.048075
#
# Validation Error:
#  Accuracy: 83.0%, Perdida test: 0.533804
#
# ----------------------------------
# Epoca 41/150
# Train Error:
#  Accuracy: 99.6%, Perdida train: 0.045228
#
# Validation Error:
#  Accuracy: 84.4%, Perdida test: 0.520802
#
# ----------------------------------
# Epoca 42/150
# Train Error:
#  Accuracy: 99.4%, Perdida train: 0.049459
#
# Validation Error:
#  Accuracy: 84.2%, Perdida test: 0.520661
#
# ----------------------------------
# Epoca 43/150
# Train Error:
#  Accuracy: 99.5%, Perdida train: 0.048835
#
# Validation Error:
#  Accuracy: 84.1%, Perdida test: 0.517820
#
# ----------------------------------
# Epoca 44/150
# Train Error:
#  Accuracy: 99.6%, Perdida train: 0.046334
#
# Validation Error:
#  Accuracy: 84.0%, Perdida test: 0.518030
#
# ----------------------------------
# Epoca 45/150
# Train Error:
#  Accuracy: 99.6%, Perdida train: 0.047387
#
# Validation Error:
#  Accuracy: 83.8%, Perdida test: 0.511072
#
# ----------------------------------
# Epoca 46/150
# Train Error:
#  Accuracy: 99.7%, Perdida train: 0.037804
#
# Validation Error:
#  Accuracy: 83.7%, Perdida test: 0.513797
#
# ----------------------------------
# Epoca 47/150
# Train Error:
#  Accuracy: 99.6%, Perdida train: 0.041231
#
# Validation Error:
#  Accuracy: 84.4%, Perdida test: 0.500099
#
# ----------------------------------
# Epoca 48/150
# Train Error:
#  Accuracy: 99.7%, Perdida train: 0.040197
#
# Validation Error:
#  Accuracy: 84.6%, Perdida test: 0.494135
#
# ----------------------------------
# Epoca 49/150
# Train Error:
#  Accuracy: 99.7%, Perdida train: 0.038475
#
# Validation Error:
#  Accuracy: 84.2%, Perdida test: 0.501555
#
# ----------------------------------
# Epoca 50/150
# Train Error:
#  Accuracy: 99.7%, Perdida train: 0.038798
#
# Validation Error:
#  Accuracy: 84.2%, Perdida test: 0.501838
#
# ----------------------------------
# Epoca 51/150
# Train Error:
#  Accuracy: 99.7%, Perdida train: 0.036340
#
# Validation Error:
#  Accuracy: 84.3%, Perdida test: 0.492523
#
# ----------------------------------
# Epoca 52/150
# Train Error:
#  Accuracy: 99.7%, Perdida train: 0.034306
#
# Validation Error:
#  Accuracy: 84.9%, Perdida test: 0.507164
#
# ----------------------------------
# Epoca 53/150
# Train Error:
#  Accuracy: 99.8%, Perdida train: 0.033910
#
# Validation Error:
#  Accuracy: 84.5%, Perdida test: 0.488135
#
# ----------------------------------
# Epoca 54/150
# Train Error:
#  Accuracy: 99.7%, Perdida train: 0.040539
#
# Validation Error:
#  Accuracy: 83.7%, Perdida test: 0.501579
#
# ----------------------------------
# Epoca 55/150
# Train Error:
#  Accuracy: 99.7%, Perdida train: 0.040418
#
# Validation Error:
#  Accuracy: 84.8%, Perdida test: 0.493050
#
# ----------------------------------
# Epoca 56/150
# Train Error:
#  Accuracy: 99.7%, Perdida train: 0.038426
#
# Validation Error:
#  Accuracy: 84.9%, Perdida test: 0.491100
#
# ----------------------------------
# Epoca 57/150
# Train Error:
#  Accuracy: 99.7%, Perdida train: 0.037133
#
# Validation Error:
#  Accuracy: 84.8%, Perdida test: 0.475142
#
# ----------------------------------
# Epoca 58/150
# Train Error:
#  Accuracy: 99.8%, Perdida train: 0.035293
#
# Validation Error:
#  Accuracy: 84.7%, Perdida test: 0.484776
#
# ----------------------------------
# Epoca 59/150
# Train Error:
#  Accuracy: 99.6%, Perdida train: 0.036809
#
# Validation Error:
#  Accuracy: 84.4%, Perdida test: 0.487326
#
# ----------------------------------
# Epoca 60/150
# Train Error:
#  Accuracy: 99.6%, Perdida train: 0.039322
#
# Validation Error:
#  Accuracy: 84.2%, Perdida test: 0.497411
#
# ----------------------------------
# Epoca 61/150
# Train Error:
#  Accuracy: 99.8%, Perdida train: 0.031760
#
# Validation Error:
#  Accuracy: 84.7%, Perdida test: 0.481916
#
# ----------------------------------
# Epoca 62/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.031198
#
# Validation Error:
#  Accuracy: 85.0%, Perdida test: 0.475244
#
# ----------------------------------
# Epoca 63/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.028375
#
# Validation Error:
#  Accuracy: 85.1%, Perdida test: 0.472838
#
# ----------------------------------
# Epoca 64/150
# Train Error:
#  Accuracy: 99.8%, Perdida train: 0.030540
#
# Validation Error:
#  Accuracy: 85.2%, Perdida test: 0.469874
#
# ----------------------------------
# Epoca 65/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.033615
#
# Validation Error:
#  Accuracy: 85.4%, Perdida test: 0.466474
#
# ----------------------------------
# Epoca 66/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.029456
#
# Validation Error:
#  Accuracy: 85.3%, Perdida test: 0.465959
#
# ----------------------------------
# Epoca 67/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.027326
#
# Validation Error:
#  Accuracy: 85.3%, Perdida test: 0.464769
#
# ----------------------------------
# Epoca 68/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.032664
#
# Validation Error:
#  Accuracy: 85.6%, Perdida test: 0.463638
#
# ----------------------------------
# Epoca 69/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.028558
#
# Validation Error:
#  Accuracy: 85.6%, Perdida test: 0.462432
#
# ----------------------------------
# Epoca 70/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.028049
#
# Validation Error:
#  Accuracy: 85.6%, Perdida test: 0.462700
#
# ----------------------------------
# Epoca 71/150
# Train Error:
#  Accuracy: 99.8%, Perdida train: 0.028005
#
# Validation Error:
#  Accuracy: 85.5%, Perdida test: 0.461793
#
# ----------------------------------
# Epoca 72/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.028372
#
# Validation Error:
#  Accuracy: 85.8%, Perdida test: 0.462817
#
# ----------------------------------
# Epoca 73/150
# Train Error:
#  Accuracy: 99.8%, Perdida train: 0.029027
#
# Validation Error:
#  Accuracy: 85.6%, Perdida test: 0.461697
#
# ----------------------------------
# Epoca 74/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.030397
#
# Validation Error:
#  Accuracy: 85.6%, Perdida test: 0.460348
#
# ----------------------------------
# Epoca 75/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.030858
#
# Validation Error:
#  Accuracy: 85.4%, Perdida test: 0.460716
#
# ----------------------------------
# Epoca 76/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.028732
#
# Validation Error:
#  Accuracy: 85.6%, Perdida test: 0.457868
#
# ----------------------------------
# Epoca 77/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.026039
#
# Validation Error:
#  Accuracy: 85.6%, Perdida test: 0.458189
#
# ----------------------------------
# Epoca 78/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.026182
#
# Validation Error:
#  Accuracy: 85.6%, Perdida test: 0.456396
#
# ----------------------------------
# Epoca 79/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.026838
#
# Validation Error:
#  Accuracy: 85.4%, Perdida test: 0.454579
#
# ----------------------------------
# Epoca 80/150
# Train Error:
#  Accuracy: 99.8%, Perdida train: 0.028291
#
# Validation Error:
#  Accuracy: 85.9%, Perdida test: 0.452358
#
# ----------------------------------
# Epoca 81/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.028171
#
# Validation Error:
#  Accuracy: 85.6%, Perdida test: 0.454073
#
# ----------------------------------
# Epoca 82/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.026792
#
# Validation Error:
#  Accuracy: 85.6%, Perdida test: 0.455591
#
# ----------------------------------
# Epoca 83/150
# Train Error:
#  Accuracy: 99.8%, Perdida train: 0.027277
#
# Validation Error:
#  Accuracy: 85.8%, Perdida test: 0.455788
#
# ----------------------------------
# Epoca 84/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.026223
#
# Validation Error:
#  Accuracy: 85.9%, Perdida test: 0.455211
#
# ----------------------------------
# Epoca 85/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.024836
#
# Validation Error:
#  Accuracy: 85.9%, Perdida test: 0.454015
#
# ----------------------------------
# Epoca 86/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.026189
#
# Validation Error:
#  Accuracy: 85.8%, Perdida test: 0.454601
#
# ----------------------------------
# Epoca 87/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.026905
#
# Validation Error:
#  Accuracy: 85.9%, Perdida test: 0.455838
#
# ----------------------------------
# Epoca 88/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.029159
#
# Validation Error:
#  Accuracy: 85.7%, Perdida test: 0.452393
#
# ----------------------------------
# Epoca 89/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.024782
#
# Validation Error:
#  Accuracy: 85.7%, Perdida test: 0.452399
#
# ----------------------------------
# Epoca 90/150
# Train Error:
#  Accuracy: 99.8%, Perdida train: 0.025685
#
# Validation Error:
#  Accuracy: 85.9%, Perdida test: 0.450791
#
# ----------------------------------
# Epoca 91/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.026980
#
# Validation Error:
#  Accuracy: 85.9%, Perdida test: 0.450450
#
# ----------------------------------
# Epoca 92/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.025371
#
# Validation Error:
#  Accuracy: 85.9%, Perdida test: 0.450619
#
# ----------------------------------
# Epoca 93/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.029402
#
# Validation Error:
#  Accuracy: 85.9%, Perdida test: 0.450273
#
# ----------------------------------
# Epoca 94/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.025774
#
# Validation Error:
#  Accuracy: 85.9%, Perdida test: 0.450003
#
# ----------------------------------
# Epoca 95/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.025988
#
# Validation Error:
#  Accuracy: 85.9%, Perdida test: 0.450042
#
# ----------------------------------
# Epoca 96/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.026458
#
# Validation Error:
#  Accuracy: 85.9%, Perdida test: 0.449801
#
# ----------------------------------
# Epoca 97/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.026582
#
# Validation Error:
#  Accuracy: 86.0%, Perdida test: 0.449933
#
# ----------------------------------
# Epoca 98/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.025030
#
# Validation Error:
#  Accuracy: 85.9%, Perdida test: 0.449823
#
# ----------------------------------
# Epoca 99/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.024321
#
# Validation Error:
#  Accuracy: 85.9%, Perdida test: 0.449832
#
# ----------------------------------
# Epoca 100/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.025300
#
# Validation Error:
#  Accuracy: 86.0%, Perdida test: 0.450070
#
# ----------------------------------
# Epoca 101/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.025895
#
# Validation Error:
#  Accuracy: 85.8%, Perdida test: 0.449987
#
# ----------------------------------
# Epoca 102/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.029789
#
# Validation Error:
#  Accuracy: 85.7%, Perdida test: 0.449268
#
# ----------------------------------
# Epoca 103/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.031785
#
# Validation Error:
#  Accuracy: 85.9%, Perdida test: 0.449549
#
# ----------------------------------
# Epoca 104/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.026148
#
# Validation Error:
#  Accuracy: 85.9%, Perdida test: 0.449690
#
# ----------------------------------
# Epoca 105/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.025420
#
# Validation Error:
#  Accuracy: 85.9%, Perdida test: 0.449637
#
# ----------------------------------
# Epoca 106/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.025711
#
# Validation Error:
#  Accuracy: 85.9%, Perdida test: 0.449669
#
# ----------------------------------
# Epoca 107/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.027576
#
# Validation Error:
#  Accuracy: 86.0%, Perdida test: 0.449648
#
# ----------------------------------
# Epoca 108/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.025850
#
# Validation Error:
#  Accuracy: 86.0%, Perdida test: 0.449504
#
# ----------------------------------
# Epoca 109/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.029171
#
# Validation Error:
#  Accuracy: 86.1%, Perdida test: 0.449695
#
# ----------------------------------
# Epoca 110/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.025004
#
# Validation Error:
#  Accuracy: 86.1%, Perdida test: 0.449320
#
# ----------------------------------
# Epoca 111/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.027014
#
# Validation Error:
#  Accuracy: 86.0%, Perdida test: 0.449211
#
# ----------------------------------
# Epoca 112/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.027442
#
# Validation Error:
#  Accuracy: 86.1%, Perdida test: 0.449120
#
# ----------------------------------
# Epoca 113/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.025667
#
# Validation Error:
#  Accuracy: 86.2%, Perdida test: 0.449261
#
# ----------------------------------
# Epoca 114/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.026729
#
# Validation Error:
#  Accuracy: 86.0%, Perdida test: 0.449240
#
# ----------------------------------
# Epoca 115/150
# Train Error:
#  Accuracy: 99.8%, Perdida train: 0.032300
#
# Validation Error:
#  Accuracy: 86.0%, Perdida test: 0.449388
#
# ----------------------------------
# Epoca 116/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.026063
#
# Validation Error:
#  Accuracy: 85.9%, Perdida test: 0.449664
#
# ----------------------------------
# Epoca 117/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.025920
#
# Validation Error:
#  Accuracy: 85.9%, Perdida test: 0.449641
#
# ----------------------------------
# Epoca 118/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.031793
#
# Validation Error:
#  Accuracy: 85.9%, Perdida test: 0.449723
#
# ----------------------------------
# Epoca 119/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.025220
#
# Validation Error:
#  Accuracy: 86.0%, Perdida test: 0.449561
#
# ----------------------------------
# Epoca 120/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.026573
#
# Validation Error:
#  Accuracy: 86.0%, Perdida test: 0.449441
#
# ----------------------------------
# Epoca 121/150
# Train Error:
#  Accuracy: 99.8%, Perdida train: 0.027346
#
# Validation Error:
#  Accuracy: 86.0%, Perdida test: 0.449439
#
# ----------------------------------
# Epoca 122/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.026088
#
# Validation Error:
#  Accuracy: 86.0%, Perdida test: 0.449394
#
# ----------------------------------
# Epoca 123/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.026192
#
# Validation Error:
#  Accuracy: 86.0%, Perdida test: 0.449401
#
# ----------------------------------
# Epoca 124/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.024161
#
# Validation Error:
#  Accuracy: 86.0%, Perdida test: 0.449373
#
# ----------------------------------
# Epoca 125/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.025696
#
# Validation Error:
#  Accuracy: 86.0%, Perdida test: 0.449371
#
# ----------------------------------
# Epoca 126/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.024598
#
# Validation Error:
#  Accuracy: 86.0%, Perdida test: 0.449359
#
# ----------------------------------
# Epoca 127/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.025853
#
# Validation Error:
#  Accuracy: 86.0%, Perdida test: 0.449344
#
# ----------------------------------
# Epoca 128/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.025955
#
# Validation Error:
#  Accuracy: 86.0%, Perdida test: 0.449355
#
# ----------------------------------
# Epoca 129/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.025471
#
# Validation Error:
#  Accuracy: 86.1%, Perdida test: 0.449346
#
# ----------------------------------
# Epoca 130/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.026596
#
# Validation Error:
#  Accuracy: 86.1%, Perdida test: 0.449321
#
# ----------------------------------
# Epoca 131/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.030133
#
# Validation Error:
#  Accuracy: 86.0%, Perdida test: 0.449278
#
# ----------------------------------
# Epoca 132/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.025973
#
# Validation Error:
#  Accuracy: 86.0%, Perdida test: 0.449280
#
# ----------------------------------
# Epoca 133/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.026626
#
# Validation Error:
#  Accuracy: 86.0%, Perdida test: 0.449200
#
# ----------------------------------
# Epoca 134/150
# Train Error:
#  Accuracy: 99.8%, Perdida train: 0.029583
#
# Validation Error:
#  Accuracy: 86.0%, Perdida test: 0.449189
#
# ----------------------------------
# Epoca 135/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.024090
#
# Validation Error:
#  Accuracy: 86.0%, Perdida test: 0.449138
#
# ----------------------------------
# Epoca 136/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.031322
#
# Validation Error:
#  Accuracy: 86.0%, Perdida test: 0.449117
#
# ----------------------------------
# Epoca 137/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.027325
#
# Validation Error:
#  Accuracy: 86.0%, Perdida test: 0.449122
#
# ----------------------------------
# Epoca 138/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.024199
#
# Validation Error:
#  Accuracy: 86.0%, Perdida test: 0.449133
#
# ----------------------------------
# Epoca 139/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.024356
#
# Validation Error:
#  Accuracy: 86.0%, Perdida test: 0.449120
#
# ----------------------------------
# Epoca 140/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.024811
#
# Validation Error:
#  Accuracy: 86.0%, Perdida test: 0.449154
#
# ----------------------------------
# Epoca 141/150
# Train Error:
#  Accuracy: 99.8%, Perdida train: 0.026313
#
# Validation Error:
#  Accuracy: 86.0%, Perdida test: 0.449172
#
# ----------------------------------
# Epoca 142/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.026606
#
# Validation Error:
#  Accuracy: 86.0%, Perdida test: 0.449189
#
# ----------------------------------
# Epoca 143/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.024790
#
# Validation Error:
#  Accuracy: 86.0%, Perdida test: 0.449162
#
# ----------------------------------
# Epoca 144/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.030782
#
# Validation Error:
#  Accuracy: 86.0%, Perdida test: 0.449165
#
# ----------------------------------
# Epoca 145/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.026939
#
# Validation Error:
#  Accuracy: 86.0%, Perdida test: 0.449119
#
# ----------------------------------
# Epoca 146/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.025949
#
# Validation Error:
#  Accuracy: 85.9%, Perdida test: 0.449139
#
# ----------------------------------
# Epoca 147/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.025571
#
# Validation Error:
#  Accuracy: 85.9%, Perdida test: 0.449100
#
# ----------------------------------
# Epoca 148/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.025973
#
# Validation Error:
#  Accuracy: 85.9%, Perdida test: 0.449061
#
# ----------------------------------
# Epoca 149/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.025482
#
# Validation Error:
#  Accuracy: 85.9%, Perdida test: 0.449037
#
# ----------------------------------
# Epoca 150/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.023982
#
# Validation Error:
#  Accuracy: 85.9%, Perdida test: 0.449052
#
# ----------------------------------

# %%
import matplotlib.pyplot as plt

#Representación de los resultados
lista = list(range(1, len(loss_validation) + 1))
plt.plot(lista, loss_train, lista , loss_validation)
plt.legend(('Training Loss', 'Validation Loss'))

# Añadir etiquetas a los ejes
plt.xlabel('Epocas')
plt.ylabel('Error')
# Out:
# Text(0, 0.5, 'Error')

# %%
#Representación de los resultados
lista = list(range(1, len(accu_validation) + 1))
plt.plot(lista, accu_train, lista , accu_validation)
plt.legend(('Training Accu', 'Validation Accu'))

# Añadir etiquetas a los ejes
plt.xlabel('Epocas')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
# Generar matriz de confusión solo para la última época
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Función para normalizar la matriz de confusión
def normalize_confusion_matrix(cm):
    return cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

cm = confusion_matrix(all_labels, all_preds)
cm_normalized = normalize_confusion_matrix(cm)
classes = [str(i) for i in range(7)]  # Asumiendo 7 clases

# Plot de la matriz de confusión normalizada
plt.figure(figsize=(10, 8))
sns.heatmap(cm_normalized, annot=True, fmt='.2f', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Normalized Confusion Matrix')
plt.show()

# %%
from sklearn.metrics import classification_report

target_names = ['class 0', 'class 1', 'class 2', 'class 3', 'class 4', 'class 5', 'class 6']
print(classification_report(all_labels, all_preds, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.83      0.91      0.87       138
#      class 1       0.88      0.87      0.87       440
#      class 2       0.87      0.86      0.86       563
#      class 3       0.85      0.86      0.85       498
#      class 4       0.87      0.85      0.86       378
#      class 5       0.84      0.86      0.85       258
#      class 6       0.85      0.74      0.79        38
#
#     accuracy                           0.86      2313
#    macro avg       0.85      0.85      0.85      2313
# weighted avg       0.86      0.86      0.86      2313
