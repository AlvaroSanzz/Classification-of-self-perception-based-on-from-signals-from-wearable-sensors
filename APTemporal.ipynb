# %% [markdown]
# <a href="https://colab.research.google.com/github/AlvaroSanzz/Classification-of-self-perception-based-on-from-signals-from-wearable-sensors/blob/main/APTemporal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import numpy as np
import xlrd
from torch.utils.data import Dataset
import pandas as pd
from sklearn.preprocessing import StandardScaler
from torch.utils.data import random_split, DataLoader
from sklearn.model_selection import train_test_split
import torch.nn as nn
import torch.nn.functional as F

# %%
#Antes de nada, si tenemos GPU la utilizamos
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

print(device)
# Out:
# cuda:0

# %%
from shutil import copyfile
from google.colab import drive
import os, sys
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# # Superprocesado

# %%
import pandas as pd
import numpy as np
import torch
from torch.utils.data import DataLoader, random_split
from sklearn.preprocessing import StandardScaler
import os
import glob

def process_excel(df):

    # Crear una lista de palabras clave a buscar en los nombres de las columnas
    palabras_clave = ["position", "acceleration", "velocity", "time"]

    # Encontrar las columnas que contienen alguna de las palabras clave en su nombre
    columnas_a_eliminar = []
    contador = 0
    for columna in df.columns:
        if any(palabra in columna.lower() for palabra in palabras_clave):
            columnas_a_eliminar.append(columna)

    # Eliminar las columnas encontradas
    df = df.drop(columns=columnas_a_eliminar)

    # Iterar sobre las filas del DataFrame en orden inverso para ajustar etiquetas
    ultimo_valor_no_cero = 0
    for indice, fila in df[::-1].iterrows():
        if fila['Label'] != 0:
            ultimo_valor_no_cero = fila['Label']
        else:
            df.at[indice, 'Label'] = ultimo_valor_no_cero

    # Eliminar filas después del último valor no cero en 'Label'
    ultimo_valor_no_cero = df.loc[df['Label'] != 0, 'Label'].iloc[-1]
    indice_ultimo_no_cero = df.loc[df['Label'] == ultimo_valor_no_cero].index[-1]
    df = df.iloc[:indice_ultimo_no_cero + 1]

    # Estandarizar columnas
    df = estandarizar_columnas(df)

    # Crear ventanas
    win_size = 300
    stp = 150
    ventanas = sliding_window_np(df, win_size, stp)

    return ventanas

def estandarizar_columnas(df):
    columnas_excluidas = ['Label']
    columnas_estandarizar = [col for col in df.columns if col not in columnas_excluidas]
    scaler = StandardScaler()
    df[columnas_estandarizar] = scaler.fit_transform(df[columnas_estandarizar])
    return df

def sliding_window_np(df, window_size, step):
    num_windows = (df.shape[0] - window_size) // step + 1
    windows = []
    for i in range(num_windows):
        start = i * step
        end = start + window_size
        window = df.iloc[start:end, :]  # Asegurarse de que la ventana tenga exactamente 'window_size' filas
        if window['Label'].nunique() == 1:
            windows.append(window)
    return windows

def one_hot_encode(labels, num_classes):
    one_hot_labels = np.zeros((len(labels), num_classes))
    for i, label in enumerate(labels):
        one_hot_labels[i, label - 1] = 1
    return one_hot_labels

def windows_to_tensors(windows, num_classes):
    tensors = []
    for window in windows:
        features = window.iloc[:, :-1].values
        labels = window.iloc[0, -1]
        labels_one_hot = one_hot_encode([labels], num_classes)[0]
        features_tensor = torch.tensor(features, dtype=torch.float32)
        labels_tensor = torch.tensor(labels_one_hot, dtype=torch.float32)
        tensors.append((features_tensor, labels_tensor))
    return tensors


# Clase para añadir ruido gaussiano
class GaussianNoiseTransform:
    def __init__(self, mean=0.0, std=1.0):
        self.mean = mean
        self.std = std

    def __call__(self, tensor):
        noise = torch.randn(tensor.size()) * self.std + self.mean
        return tensor + noise

# Clase de dataset personalizada
class CustomDataset(Dataset):
    def __init__(self, data, transform=None):
        self.data = data
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        x, y = self.data[idx]
        if self.transform:
            x = self.transform(x)
        return x, y

# %%
all_windows = []
num_classes = 7

path = '/content/drive/My Drive/TFG/RokokoFiles/'

# Buscar todos los archivos CSV en el directorio actual
csv_files = glob.glob(path + '*.csv')

print(csv_files)

# Leer cada archivo CSV y almacenarlos en DataFrames separados

for file in csv_files:
  df = pd.read_csv(file)

  # for file_path in file_paths:
  ventanas = process_excel(df)
  tensor_data = windows_to_tensors(ventanas, num_classes)
  all_windows.extend(tensor_data)

print("EL numero de ventanas es: ", len(all_windows))
print("EL numero de ventanas es: ", len(ventanas))
print("El numero de filas y columnas de cada ventana es: ",ventanas[0].shape)


# Dividir los datos combinados en conjuntos de entrenamiento y prueba
generator = torch.Generator().manual_seed(42)
train_val_size = int(0.8 * len(all_windows))  # Supongamos que queremos el 80% para entrenamiento y validación combinados
test_val_size = len(all_windows) - train_val_size

trainset, testset = random_split(all_windows, [train_val_size, test_val_size], generator=generator)


# Añadir ruido gaussiano solo al conjunto de entrenamiento
gaussian_transform = GaussianNoiseTransform(mean=0.0, std=0.1)
trainset = CustomDataset(trainset, transform=gaussian_transform)
# Out:
# ['/content/drive/My Drive/TFG/RokokoFiles/[p185] control-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p185] high-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p185] high-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p185] low-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p186] control-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p186] control-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p186] high-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p186] high-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p186] low-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p188] control-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p188] control-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p188] high-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p188] high-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p188] low-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p188] low-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p189] control-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p189] control-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p189] high-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p189] low-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p192] control-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p192] control-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p192] high-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p192] low-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p192] low-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p193] control-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p193] high-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p193] control-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p193] low-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p193] high-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p193] low-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p195] control-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p195] control-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p195] high-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p195] high-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p195] low-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p195] low-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p197] control-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p197] control-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p197] high-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p197] high-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p197] low-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p197] low-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p201] control-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p201] control-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p201] high-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p201] low-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p202] control-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p202] control-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p202] high-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p202] low-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p205] control-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p205] low-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p205] high-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p205] low-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p206] control-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p206] high-1 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p206] high-2 Rokoko.csv', '/content/drive/My Drive/TFG/RokokoFiles/[p206] low-1 Rokoko.csv', '/content/ ...
# EL numero de ventanas es:  11563
# EL numero de ventanas es:  45
# El numero de filas y columnas de cada ventana es:  (300, 52)

# %%
class CustomDataLoader_4D(DataLoader):
    def __init__(self, dataset, batch_size, shuffle, add_channel_dim=True):
        super().__init__(dataset, batch_size, shuffle)
        self.add_channel_dim = add_channel_dim

    def __iter__(self):
        for batch in super().__iter__():
            if self.add_channel_dim:
                batch = self.add_channel_dimension(batch)
            yield batch

    def add_channel_dimension(self, batch):
        data, labels = batch
        data = data.unsqueeze(1)  # Agregar una dimensión de canal
        return data, labels

batch_size = 16
trainloader = CustomDataLoader_4D(trainset, batch_size, shuffle=True)
testloader = CustomDataLoader_4D(testset, batch_size, shuffle=False)

# Verificar la forma del primer lote de datos
for batch_data, batch_labels in trainloader:
    print("Dimensiones del lote de datos:", batch_data.shape)
    print("Dimensiones del lote de etiquetas:", batch_labels.shape)
    break  # Detener después de imprimir el primer lote
# Out:
# Dimensiones del lote de datos: torch.Size([16, 1, 300, 51])
# Dimensiones del lote de etiquetas: torch.Size([16, 7])

# %%
print("Tamaño del conjunto de entrenamiento:", len(trainset))
print("Tamaño del conjunto de test:", len(testset))
# Out:
# Tamaño del conjunto de entrenamiento: 9250
# Tamaño del conjunto de test: 2313

# %% [markdown]
# # Constucción de la red

# %% [markdown]
# Primero definiremos las capas

# %%
class Net(nn.Module):
  def __init__(self):
      super(Net, self).__init__()

      # Bloque #1
      self.conv1 = nn.Conv2d(1, 4, 3, padding=1) #poner padding 1
      self.bn1 = nn.BatchNorm2d(4)
      self.conv2 = nn.Conv2d(4, 8, 3, padding=1)
      self.bn2 = nn.BatchNorm2d(8)

      # Bloque #2
      self.conv3 = nn.Conv2d(8, 16, 3, padding=1)
      self.bn3 = nn.BatchNorm2d(16)
      self.conv4 = nn.Conv2d(16, 32, 3, padding=1)
      self.bn4 = nn.BatchNorm2d(32)

      # Bloque #3
      self.conv5 = nn.Conv2d(32, 64, 3, padding=1)
      self.bn5 = nn.BatchNorm2d(64)
      self.conv6 = nn.Conv2d(64, 128, 3, padding=1)
      self.bn6 = nn.BatchNorm2d(128)

      # Bloque #4
      self.conv7 = nn.Conv2d(128, 256, 3, padding=1)
      self.bn7 = nn.BatchNorm2d(256)
      self.conv8 = nn.Conv2d(256, 512, 3, padding=1)
      self.bn8 = nn.BatchNorm2d(512)

      self.pool = nn.MaxPool2d(3, stride=(2, 1), padding=1)

      self.avgpool = nn.AdaptiveAvgPool2d((1, 51))

      self.conv1x1 = nn.Conv2d(51, 1, 1)

      self.fc1 = nn.Linear(512, 128)
      self.fc2 = nn.Linear(128, 256)
      self.fc3 = nn.Linear(256, 7)

      self.bn1d1 = nn.BatchNorm1d(128)
      self.bn1d2 = nn.BatchNorm1d(256)

      self.dropout1 = nn.Dropout(p=0.5)
      self.dropout2 = nn.Dropout(p=0.5)

  def forward(self, x):

    x = F.relu(self.bn1(self.conv1(x)))
    x = self.pool(F.relu(self.bn2(self.conv2(x))))

    x = F.relu(self.bn3(self.conv3(x)))
    x = self.pool(F.relu(self.bn4(self.conv4(x))))

    x = F.relu(self.bn5(self.conv5(x)))
    x = self.pool(F.relu(self.bn6(self.conv6(x))))

    x = F.relu(self.bn7(self.conv7(x)))
    x = self.pool(F.relu(self.bn8(self.conv8(x))))

    x = self.avgpool(x)

    x = x.permute(0, 3, 2, 1)

    x = self.conv1x1(x)

    x = x.flatten(start_dim=1)

    x = F.relu(self.bn1d1(self.fc1(x)))
    # x = self.dropout1(x)
    x = F.relu(self.bn1d2(self.fc2(x)))
    # x = self.dropout2(x)
    x = self.fc3(x)

    return x

# %%
import random
import numpy.random as npr

#We fix seeds for reproducibility
random.seed(42)
npr.seed(42)
torch.manual_seed(42)
torch.backends.cudnn.benchmark = True

net = Net() #Invocamos el constructor de la red (método init())
net.to(device) #Pasamos la red al device que estemos usando (gpu)
# Out:
# Net(
#   (conv1): Conv2d(1, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(4, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn2): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn3): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv5): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv6): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn6): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv7): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn7): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv8): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn8): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool): MaxPool2d(kernel_size=3, stride=(2, 1), padding=1, dilation=1, ceil_mode=False)
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 51))
#   (conv1x1): Conv2d(51, 1, kernel_size=(1, 1), stride=(1, 1))
#   (fc1): Linear(in_features=512, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=7, bias=True)
#   (bn1d1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn1d2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout1): Dropout(p=0.5, inplace=False)
#   (dropout2): Dropout(p=0.5, inplace=False)
# )

# %% [markdown]
# Testeo para comprobar la dimension de nuestros datos al entrar al salir de la red

# %% [markdown]
# # Entrenamiento

# %%
data=next(iter(trainloader))
inputs = data[0].to(device).float()  # Tomamos la primera imagen y le agregamos una dimensión de lote
labels = data[1].to(device)  # Tomamos la primera etiqueta y le agregamos una dimensión de lote

x = inputs.to(device)
print(x.shape)

print("Forma de la imagen:", inputs.shape)
print("Forma de la etiqueta:", labels.shape)
with torch.set_grad_enabled(False):
    outputs = net(inputs)

    print('El tamaño del tensor de salida es {}'.format(outputs.shape))
# Out:
# torch.Size([16, 1, 300, 51])
# Forma de la imagen: torch.Size([16, 1, 300, 51])
# Forma de la etiqueta: torch.Size([16, 7])
# El tamaño del tensor de salida es torch.Size([16, 7])

# %% [markdown]
# ## Entrenamiento

# %%
def train_loop(trainDataloader, model, criterion, optimizer):
    size = len(trainDataloader.dataset)
    epoch_loss = 0.0  # Inicializar la pérdida de la época
    epoch_correct = 0.0

    for inputs, labels in trainDataloader:  # Iterar sobre el dataloader
      inputs = inputs.to(device).float()  # Mover las imágenes al dispositivo y convertirlas a flotantes
      labels = labels.to(device)  # Mover las etiquetas al dispositivo

      y_pred = model(inputs)  # Realizar predicciones
      loss = criterion(y_pred, labels)  # Calcular la pérdida

      optimizer.zero_grad()  # Reiniciar los gradientes
      loss.backward()  # Realizar la retropropagación
      optimizer.step()  # Actualizar los parámetros

      epoch_loss += loss.item()  # Acumular la pérdida de la muestra actual en la pérdida de la época
      epoch_correct += torch.sum( torch.argmax(y_pred, axis=1) == torch.argmax(labels, axis=1)).item()

    epoch_loss /= len(trainloader)  # Calcular el promedio de la pérdida de la época
    epoch_correct /= size
    print(f"Train Error:\n Accuracy: {(100 * epoch_correct):>0.1f}%, Perdida train: {epoch_loss:>5f}\n")
    return epoch_loss, epoch_correct

def validation_loop(dataloader, model, criterion):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    total_correct = 0
    total_loss = 0
    all_preds = []
    all_labels = []
    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs = inputs.to(device).float()
            labels = labels.to(device)
            y_pred = model(inputs)
            loss = criterion(y_pred, labels)
            indicemax = torch.argmax(y_pred, axis=1)
            predicted_onehot = torch.zeros_like(y_pred)
            # predicted_onehot[indicemax] = 1
            predicted_labels = torch.argmax(y_pred, axis=1)  # Obtener la etiqueta predicha unidimensional
            true_labels = torch.argmax(labels, axis=1) #etiqueta verdadera unidimensional
            total_loss += loss.item()
            all_preds.extend(torch.argmax(y_pred, axis=1).cpu().numpy())
            all_labels.extend(torch.argmax(labels, axis=1).cpu().numpy())

            # print("y_pred: ", y_pred)
            # print("labels: ", labels)

            # Calcular el número total de predicciones correctas
            total_correct += torch.sum( torch.argmax(y_pred, axis=1) == torch.argmax(labels, axis=1)).item()
    # Calcular la precisión y la pérdida promedio
    total_correct /= size
    total_loss /= num_batches
    print(f"Validation Error:\n Accuracy: {(100 * total_correct):>0.1f}%, Perdida test: {total_loss:>5f}\n")
    return total_loss, total_correct, all_labels, all_preds

# %%
num_epochs = 150
criterion = torch.nn.CrossEntropyLoss()
model = Net().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, weight_decay=0.005)

# Añadir un StepLR scheduler
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=30, gamma=0.1)

loss_train, accu_train = np.zeros(num_epochs), np.zeros(num_epochs)
loss_validation, accu_validation = np.zeros(num_epochs), np.zeros(num_epochs)

for epoch in range(num_epochs):
    print(f"Epoca {epoch + 1}/{num_epochs}")
    loss_train[epoch], accu_train[epoch] = train_loop(trainloader, model, criterion, optimizer)
    loss_validation[epoch], accu_validation[epoch], all_labels, all_preds = validation_loop(testloader, model, criterion)

    # Actualizar el learning rate según el scheduler
    scheduler.step()

    print("----------------------------------")
# Out:
# Epoca 1/150
# Train Error:
#  Accuracy: 26.6%, Perdida train: 1.785061
#
# Validation Error:
#  Accuracy: 30.8%, Perdida test: 1.692268
#
# ----------------------------------
# Epoca 2/150
# Train Error:
#  Accuracy: 34.2%, Perdida train: 1.636235
#
# Validation Error:
#  Accuracy: 36.3%, Perdida test: 1.577799
#
# ----------------------------------
# Epoca 3/150
# Train Error:
#  Accuracy: 42.7%, Perdida train: 1.486764
#
# Validation Error:
#  Accuracy: 41.9%, Perdida test: 1.481732
#
# ----------------------------------
# Epoca 4/150
# Train Error:
#  Accuracy: 51.2%, Perdida train: 1.304269
#
# Validation Error:
#  Accuracy: 45.2%, Perdida test: 1.374797
#
# ----------------------------------
# Epoca 5/150
# Train Error:
#  Accuracy: 57.4%, Perdida train: 1.148384
#
# Validation Error:
#  Accuracy: 54.0%, Perdida test: 1.223434
#
# ----------------------------------
# Epoca 6/150
# Train Error:
#  Accuracy: 61.3%, Perdida train: 1.059787
#
# Validation Error:
#  Accuracy: 55.8%, Perdida test: 1.139137
#
# ----------------------------------
# Epoca 7/150
# Train Error:
#  Accuracy: 73.5%, Perdida train: 0.773320
#
# Validation Error:
#  Accuracy: 63.4%, Perdida test: 0.987997
#
# ----------------------------------
# Epoca 8/150
# Train Error:
#  Accuracy: 79.9%, Perdida train: 0.597689
#
# Validation Error:
#  Accuracy: 65.8%, Perdida test: 0.907641
#
# ----------------------------------
# Epoca 9/150
# Train Error:
#  Accuracy: 85.2%, Perdida train: 0.465977
#
# Validation Error:
#  Accuracy: 69.4%, Perdida test: 0.836736
#
# ----------------------------------
# Epoca 10/150
# Train Error:
#  Accuracy: 86.8%, Perdida train: 0.408385
#
# Validation Error:
#  Accuracy: 73.3%, Perdida test: 0.770154
#
# ----------------------------------
# Epoca 11/150
# Train Error:
#  Accuracy: 91.9%, Perdida train: 0.284724
#
# Validation Error:
#  Accuracy: 74.3%, Perdida test: 0.748993
#
# ----------------------------------
# Epoca 12/150
# Train Error:
#  Accuracy: 91.6%, Perdida train: 0.276637
#
# Validation Error:
#  Accuracy: 76.7%, Perdida test: 0.663837
#
# ----------------------------------
# Epoca 13/150
# Train Error:
#  Accuracy: 93.9%, Perdida train: 0.208598
#
# Validation Error:
#  Accuracy: 78.0%, Perdida test: 0.645494
#
# ----------------------------------
# Epoca 14/150
# Train Error:
#  Accuracy: 94.3%, Perdida train: 0.199180
#
# Validation Error:
#  Accuracy: 77.3%, Perdida test: 0.667973
#
# ----------------------------------
# Epoca 15/150
# Train Error:
#  Accuracy: 92.6%, Perdida train: 0.233606
#
# Validation Error:
#  Accuracy: 80.2%, Perdida test: 0.600755
#
# ----------------------------------
# Epoca 16/150
# Train Error:
#  Accuracy: 95.4%, Perdida train: 0.174448
#
# Validation Error:
#  Accuracy: 79.1%, Perdida test: 0.631757
#
# ----------------------------------
# Epoca 17/150
# Train Error:
#  Accuracy: 95.0%, Perdida train: 0.170582
#
# Validation Error:
#  Accuracy: 78.8%, Perdida test: 0.654134
#
# ----------------------------------
# Epoca 18/150
# Train Error:
#  Accuracy: 94.7%, Perdida train: 0.180544
#
# Validation Error:
#  Accuracy: 79.7%, Perdida test: 0.609763
#
# ----------------------------------
# Epoca 19/150
# Train Error:
#  Accuracy: 96.3%, Perdida train: 0.133956
#
# Validation Error:
#  Accuracy: 81.6%, Perdida test: 0.565956
#
# ----------------------------------
# Epoca 20/150
# Train Error:
#  Accuracy: 95.3%, Perdida train: 0.159270
#
# Validation Error:
#  Accuracy: 80.8%, Perdida test: 0.604547
#
# ----------------------------------
# Epoca 21/150
# Train Error:
#  Accuracy: 96.6%, Perdida train: 0.126800
#
# Validation Error:
#  Accuracy: 81.9%, Perdida test: 0.557510
#
# ----------------------------------
# Epoca 22/150
# Train Error:
#  Accuracy: 95.7%, Perdida train: 0.146882
#
# Validation Error:
#  Accuracy: 81.3%, Perdida test: 0.584294
#
# ----------------------------------
# Epoca 23/150
# Train Error:
#  Accuracy: 96.6%, Perdida train: 0.131050
#
# Validation Error:
#  Accuracy: 80.3%, Perdida test: 0.597787
#
# ----------------------------------
# Epoca 24/150
# Train Error:
#  Accuracy: 96.6%, Perdida train: 0.130823
#
# Validation Error:
#  Accuracy: 80.0%, Perdida test: 0.603870
#
# ----------------------------------
# Epoca 25/150
# Train Error:
#  Accuracy: 96.6%, Perdida train: 0.129577
#
# Validation Error:
#  Accuracy: 80.9%, Perdida test: 0.568390
#
# ----------------------------------
# Epoca 26/150
# Train Error:
#  Accuracy: 93.5%, Perdida train: 0.214675
#
# Validation Error:
#  Accuracy: 83.6%, Perdida test: 0.526901
#
# ----------------------------------
# Epoca 27/150
# Train Error:
#  Accuracy: 97.5%, Perdida train: 0.106918
#
# Validation Error:
#  Accuracy: 83.5%, Perdida test: 0.525403
#
# ----------------------------------
# Epoca 28/150
# Train Error:
#  Accuracy: 96.4%, Perdida train: 0.132716
#
# Validation Error:
#  Accuracy: 81.5%, Perdida test: 0.576638
#
# ----------------------------------
# Epoca 29/150
# Train Error:
#  Accuracy: 97.6%, Perdida train: 0.096780
#
# Validation Error:
#  Accuracy: 82.3%, Perdida test: 0.543165
#
# ----------------------------------
# Epoca 30/150
# Train Error:
#  Accuracy: 97.6%, Perdida train: 0.096110
#
# Validation Error:
#  Accuracy: 81.3%, Perdida test: 0.590695
#
# ----------------------------------
# Epoca 31/150
# Train Error:
#  Accuracy: 98.7%, Perdida train: 0.067724
#
# Validation Error:
#  Accuracy: 86.6%, Perdida test: 0.424965
#
# ----------------------------------
# Epoca 32/150
# Train Error:
#  Accuracy: 99.6%, Perdida train: 0.038653
#
# Validation Error:
#  Accuracy: 87.6%, Perdida test: 0.394869
#
# ----------------------------------
# Epoca 33/150
# Train Error:
#  Accuracy: 99.7%, Perdida train: 0.033298
#
# Validation Error:
#  Accuracy: 88.5%, Perdida test: 0.378136
#
# ----------------------------------
# Epoca 34/150
# Train Error:
#  Accuracy: 99.8%, Perdida train: 0.029261
#
# Validation Error:
#  Accuracy: 88.8%, Perdida test: 0.374469
#
# ----------------------------------
# Epoca 35/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.025357
#
# Validation Error:
#  Accuracy: 88.9%, Perdida test: 0.360318
#
# ----------------------------------
# Epoca 36/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.024654
#
# Validation Error:
#  Accuracy: 89.4%, Perdida test: 0.342998
#
# ----------------------------------
# Epoca 37/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.027581
#
# Validation Error:
#  Accuracy: 89.3%, Perdida test: 0.336678
#
# ----------------------------------
# Epoca 38/150
# Train Error:
#  Accuracy: 99.8%, Perdida train: 0.026812
#
# Validation Error:
#  Accuracy: 89.4%, Perdida test: 0.337622
#
# ----------------------------------
# Epoca 39/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.020249
#
# Validation Error:
#  Accuracy: 89.9%, Perdida test: 0.330408
#
# ----------------------------------
# Epoca 40/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.025100
#
# Validation Error:
#  Accuracy: 90.3%, Perdida test: 0.328002
#
# ----------------------------------
# Epoca 41/150
# Train Error:
#  Accuracy: 99.8%, Perdida train: 0.024258
#
# Validation Error:
#  Accuracy: 90.5%, Perdida test: 0.320331
#
# ----------------------------------
# Epoca 42/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.020415
#
# Validation Error:
#  Accuracy: 90.8%, Perdida test: 0.314791
#
# ----------------------------------
# Epoca 43/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.020507
#
# Validation Error:
#  Accuracy: 90.2%, Perdida test: 0.317038
#
# ----------------------------------
# Epoca 44/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.026173
#
# Validation Error:
#  Accuracy: 90.2%, Perdida test: 0.316466
#
# ----------------------------------
# Epoca 45/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.023530
#
# Validation Error:
#  Accuracy: 91.0%, Perdida test: 0.311878
#
# ----------------------------------
# Epoca 46/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.021581
#
# Validation Error:
#  Accuracy: 90.5%, Perdida test: 0.314306
#
# ----------------------------------
# Epoca 47/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.020013
#
# Validation Error:
#  Accuracy: 90.6%, Perdida test: 0.309074
#
# ----------------------------------
# Epoca 48/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.023347
#
# Validation Error:
#  Accuracy: 90.9%, Perdida test: 0.304451
#
# ----------------------------------
# Epoca 49/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.022943
#
# Validation Error:
#  Accuracy: 90.7%, Perdida test: 0.310021
#
# ----------------------------------
# Epoca 50/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.021192
#
# Validation Error:
#  Accuracy: 90.6%, Perdida test: 0.307728
#
# ----------------------------------
# Epoca 51/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.020009
#
# Validation Error:
#  Accuracy: 90.8%, Perdida test: 0.302912
#
# ----------------------------------
# Epoca 52/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.021697
#
# Validation Error:
#  Accuracy: 90.3%, Perdida test: 0.308299
#
# ----------------------------------
# Epoca 53/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.020030
#
# Validation Error:
#  Accuracy: 91.1%, Perdida test: 0.302475
#
# ----------------------------------
# Epoca 54/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.020511
#
# Validation Error:
#  Accuracy: 90.9%, Perdida test: 0.300247
#
# ----------------------------------
# Epoca 55/150
# Train Error:
#  Accuracy: 99.9%, Perdida train: 0.021449
#
# Validation Error:
#  Accuracy: 91.2%, Perdida test: 0.297722
#
# ----------------------------------
# Epoca 56/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.018570
#
# Validation Error:
#  Accuracy: 91.5%, Perdida test: 0.292606
#
# ----------------------------------
# Epoca 57/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.020725
#
# Validation Error:
#  Accuracy: 91.9%, Perdida test: 0.292243
#
# ----------------------------------
# Epoca 58/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.019623
#
# Validation Error:
#  Accuracy: 91.8%, Perdida test: 0.294751
#
# ----------------------------------
# Epoca 59/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.020558
#
# Validation Error:
#  Accuracy: 91.8%, Perdida test: 0.288114
#
# ----------------------------------
# Epoca 60/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.019591
#
# Validation Error:
#  Accuracy: 92.0%, Perdida test: 0.279030
#
# ----------------------------------
# Epoca 61/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.018833
#
# Validation Error:
#  Accuracy: 92.0%, Perdida test: 0.278264
#
# ----------------------------------
# Epoca 62/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.018772
#
# Validation Error:
#  Accuracy: 92.0%, Perdida test: 0.277865
#
# ----------------------------------
# Epoca 63/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.020385
#
# Validation Error:
#  Accuracy: 92.1%, Perdida test: 0.276958
#
# ----------------------------------
# Epoca 64/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.018757
#
# Validation Error:
#  Accuracy: 92.1%, Perdida test: 0.276266
#
# ----------------------------------
# Epoca 65/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.020683
#
# Validation Error:
#  Accuracy: 92.1%, Perdida test: 0.275260
#
# ----------------------------------
# Epoca 66/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.018825
#
# Validation Error:
#  Accuracy: 92.1%, Perdida test: 0.275355
#
# ----------------------------------
# Epoca 67/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.018933
#
# Validation Error:
#  Accuracy: 92.1%, Perdida test: 0.275475
#
# ----------------------------------
# Epoca 68/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.018590
#
# Validation Error:
#  Accuracy: 92.2%, Perdida test: 0.274846
#
# ----------------------------------
# Epoca 69/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.018024
#
# Validation Error:
#  Accuracy: 92.0%, Perdida test: 0.274718
#
# ----------------------------------
# Epoca 70/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.020719
#
# Validation Error:
#  Accuracy: 92.1%, Perdida test: 0.274701
#
# ----------------------------------
# Epoca 71/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.019818
#
# Validation Error:
#  Accuracy: 92.3%, Perdida test: 0.274270
#
# ----------------------------------
# Epoca 72/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.018457
#
# Validation Error:
#  Accuracy: 92.3%, Perdida test: 0.274230
#
# ----------------------------------
# Epoca 73/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.017331
#
# Validation Error:
#  Accuracy: 92.1%, Perdida test: 0.274064
#
# ----------------------------------
# Epoca 74/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.018610
#
# Validation Error:
#  Accuracy: 92.3%, Perdida test: 0.274102
#
# ----------------------------------
# Epoca 75/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.018265
#
# Validation Error:
#  Accuracy: 92.3%, Perdida test: 0.274003
#
# ----------------------------------
# Epoca 76/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.018597
#
# Validation Error:
#  Accuracy: 92.2%, Perdida test: 0.272998
#
# ----------------------------------
# Epoca 77/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.018186
#
# Validation Error:
#  Accuracy: 92.4%, Perdida test: 0.272273
#
# ----------------------------------
# Epoca 78/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.021544
#
# Validation Error:
#  Accuracy: 92.4%, Perdida test: 0.272566
#
# ----------------------------------
# Epoca 79/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.017638
#
# Validation Error:
#  Accuracy: 92.4%, Perdida test: 0.272935
#
# ----------------------------------
# Epoca 80/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.017628
#
# Validation Error:
#  Accuracy: 92.4%, Perdida test: 0.272698
#
# ----------------------------------
# Epoca 81/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.017974
#
# Validation Error:
#  Accuracy: 92.3%, Perdida test: 0.273117
#
# ----------------------------------
# Epoca 82/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.018300
#
# Validation Error:
#  Accuracy: 92.4%, Perdida test: 0.273053
#
# ----------------------------------
# Epoca 83/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.019031
#
# Validation Error:
#  Accuracy: 92.4%, Perdida test: 0.272412
#
# ----------------------------------
# Epoca 84/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.017733
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.272139
#
# ----------------------------------
# Epoca 85/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.016909
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.272211
#
# ----------------------------------
# Epoca 86/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.022108
#
# Validation Error:
#  Accuracy: 92.3%, Perdida test: 0.272594
#
# ----------------------------------
# Epoca 87/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.018305
#
# Validation Error:
#  Accuracy: 92.3%, Perdida test: 0.272754
#
# ----------------------------------
# Epoca 88/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.017796
#
# Validation Error:
#  Accuracy: 92.3%, Perdida test: 0.272941
#
# ----------------------------------
# Epoca 89/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.018183
#
# Validation Error:
#  Accuracy: 92.3%, Perdida test: 0.271789
#
# ----------------------------------
# Epoca 90/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.017528
#
# Validation Error:
#  Accuracy: 92.4%, Perdida test: 0.271385
#
# ----------------------------------
# Epoca 91/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.021972
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.271390
#
# ----------------------------------
# Epoca 92/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.023043
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.271405
#
# ----------------------------------
# Epoca 93/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.017946
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.271397
#
# ----------------------------------
# Epoca 94/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.017429
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.271335
#
# ----------------------------------
# Epoca 95/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.018573
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.271263
#
# ----------------------------------
# Epoca 96/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.016967
#
# Validation Error:
#  Accuracy: 92.6%, Perdida test: 0.271301
#
# ----------------------------------
# Epoca 97/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.018549
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.271281
#
# ----------------------------------
# Epoca 98/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.018610
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.271264
#
# ----------------------------------
# Epoca 99/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.021401
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.271246
#
# ----------------------------------
# Epoca 100/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.018772
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.271173
#
# ----------------------------------
# Epoca 101/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.016940
#
# Validation Error:
#  Accuracy: 92.6%, Perdida test: 0.271181
#
# ----------------------------------
# Epoca 102/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.018183
#
# Validation Error:
#  Accuracy: 92.6%, Perdida test: 0.271113
#
# ----------------------------------
# Epoca 103/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.016497
#
# Validation Error:
#  Accuracy: 92.6%, Perdida test: 0.271152
#
# ----------------------------------
# Epoca 104/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.019103
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.271129
#
# ----------------------------------
# Epoca 105/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.021147
#
# Validation Error:
#  Accuracy: 92.6%, Perdida test: 0.271175
#
# ----------------------------------
# Epoca 106/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.022366
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.271187
#
# ----------------------------------
# Epoca 107/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.017862
#
# Validation Error:
#  Accuracy: 92.6%, Perdida test: 0.271201
#
# ----------------------------------
# Epoca 108/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.017023
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.271216
#
# ----------------------------------
# Epoca 109/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.019204
#
# Validation Error:
#  Accuracy: 92.6%, Perdida test: 0.271290
#
# ----------------------------------
# Epoca 110/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.017991
#
# Validation Error:
#  Accuracy: 92.6%, Perdida test: 0.271188
#
# ----------------------------------
# Epoca 111/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.022053
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.271163
#
# ----------------------------------
# Epoca 112/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.019207
#
# Validation Error:
#  Accuracy: 92.4%, Perdida test: 0.271241
#
# ----------------------------------
# Epoca 113/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.018652
#
# Validation Error:
#  Accuracy: 92.4%, Perdida test: 0.271331
#
# ----------------------------------
# Epoca 114/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.017434
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.271263
#
# ----------------------------------
# Epoca 115/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.017783
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.271184
#
# ----------------------------------
# Epoca 116/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.017152
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.271139
#
# ----------------------------------
# Epoca 117/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.018200
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.271049
#
# ----------------------------------
# Epoca 118/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.017983
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.271042
#
# ----------------------------------
# Epoca 119/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.017584
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.271034
#
# ----------------------------------
# Epoca 120/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.018341
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.271049
#
# ----------------------------------
# Epoca 121/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.022377
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.271042
#
# ----------------------------------
# Epoca 122/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.018925
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.271037
#
# ----------------------------------
# Epoca 123/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.017524
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.271028
#
# ----------------------------------
# Epoca 124/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.018342
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.271017
#
# ----------------------------------
# Epoca 125/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.022844
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.271012
#
# ----------------------------------
# Epoca 126/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.017743
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.271009
#
# ----------------------------------
# Epoca 127/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.017491
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.271003
#
# ----------------------------------
# Epoca 128/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.017628
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.270991
#
# ----------------------------------
# Epoca 129/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.019733
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.270986
#
# ----------------------------------
# Epoca 130/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.017893
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.270983
#
# ----------------------------------
# Epoca 131/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.018080
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.270977
#
# ----------------------------------
# Epoca 132/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.016853
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.270973
#
# ----------------------------------
# Epoca 133/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.016997
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.270963
#
# ----------------------------------
# Epoca 134/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.018387
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.270953
#
# ----------------------------------
# Epoca 135/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.022421
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.270949
#
# ----------------------------------
# Epoca 136/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.018447
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.270944
#
# ----------------------------------
# Epoca 137/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.021485
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.270941
#
# ----------------------------------
# Epoca 138/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.017845
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.270948
#
# ----------------------------------
# Epoca 139/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.017573
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.270947
#
# ----------------------------------
# Epoca 140/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.019691
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.270936
#
# ----------------------------------
# Epoca 141/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.021757
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.270922
#
# ----------------------------------
# Epoca 142/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.018350
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.270922
#
# ----------------------------------
# Epoca 143/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.021864
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.270921
#
# ----------------------------------
# Epoca 144/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.017073
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.270911
#
# ----------------------------------
# Epoca 145/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.018092
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.270914
#
# ----------------------------------
# Epoca 146/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.018582
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.270908
#
# ----------------------------------
# Epoca 147/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.021040
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.270893
#
# ----------------------------------
# Epoca 148/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.018370
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.270892
#
# ----------------------------------
# Epoca 149/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.017513
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.270888
#
# ----------------------------------
# Epoca 150/150
# Train Error:
#  Accuracy: 100.0%, Perdida train: 0.019367
#
# Validation Error:
#  Accuracy: 92.5%, Perdida test: 0.270876
#
# ----------------------------------

# %%
import matplotlib.pyplot as plt

#Representación de los resultados
lista = list(range(1, len(loss_validation) + 1))
plt.plot(lista, loss_train, lista , loss_validation)
plt.legend(('Training Loss', 'Validation Loss'))

# Añadir etiquetas a los ejes
plt.xlabel('Epocas')
plt.ylabel('Error')
# Out:
# Text(0, 0.5, 'Error')

# %%
#Representación de los resultados
lista = list(range(1, len(accu_validation) + 1))
plt.plot(lista, accu_train, lista , accu_validation)
plt.legend(('Training Accu', 'Validation Accu'))

# Añadir etiquetas a los ejes
plt.xlabel('Epocas')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
# Generar matriz de confusión solo para la última época
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Función para normalizar la matriz de confusión
def normalize_confusion_matrix(cm):
    return cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

cm = confusion_matrix(all_labels, all_preds)
cm_normalized = normalize_confusion_matrix(cm)
classes = [str(i) for i in range(7)]  # Asumiendo 7 clases

# Plot de la matriz de confusión normalizada
plt.figure(figsize=(10, 8))
sns.heatmap(cm_normalized, annot=True, fmt='.2f', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Normalized Confusion Matrix')
plt.show()

# %%
from sklearn.metrics import classification_report

target_names = ['class 0', 'class 1', 'class 2', 'class 3', 'class 4', 'class 5', 'class 6']
print(classification_report(all_labels, all_preds, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.92      0.94      0.93       138
#      class 1       0.92      0.91      0.92       440
#      class 2       0.94      0.91      0.92       563
#      class 3       0.90      0.94      0.92       498
#      class 4       0.95      0.91      0.93       378
#      class 5       0.92      0.95      0.93       258
#      class 6       0.97      0.95      0.96        38
#
#     accuracy                           0.92      2313
#    macro avg       0.93      0.93      0.93      2313
# weighted avg       0.93      0.92      0.92      2313
